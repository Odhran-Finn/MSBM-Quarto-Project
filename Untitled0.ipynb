# %%
# !pip install praise
# Out:
# Collecting praise
#   Downloading praise-0.1.zip (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: praise
#   Building wheel for praise (setup.py) ... done
#   Created wheel for praise: filename=praise-0.1-py3-none-any.whl size=4137 sha256=7ad616b41487839a2a8f045655ca34d6ab2c850490b988d80ec3c3ea3c59eabf
#   Stored in directory: /root/.cache/pip/wheels/9d/46/b4/664d90e15409124eb3fd46ba8470e6788fb7e2467b26a03219
# Successfully built praise
# Installing collected packages: praise
# Successfully installed praise-0.1

# %%
import praise as pr

# %%
pr.praise()
# Out:
# 'You are just wow!'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Data
my_power = [0.5, 99.5]
my_knowledge = ["without python", "with python"]
# Create bar plot
plt.bar(my_knowledge, my_power)
# Add labels
plt.xlabel("Knowledge Level")
plt.ylabel("Power (%)")
plt.title("Bar Plot Example")
# Show plot
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/content/unicef_metadata.csv')
display(df.head())
# Out:
#        country alpha_2_code alpha_3_code  numeric_code  year  \
# 0  Afghanistan           AF          AFG             4  1960
# 1  Afghanistan           AF          AFG             4  1961
# 2  Afghanistan           AF          AFG             4  1962
# 3  Afghanistan           AF          AFG             4  1963
# 4  Afghanistan           AF          AFG             4  1964
#
#    Population, total  GDP per capita (constant 2015 US$)  GNI (current US$)  \
# 0          9035043.0                                 NaN       5.488888e+08
# 1          9214083.0                                 NaN       5.600000e+08
# 2          9404406.0                                 NaN       5.577778e+08
# 3          9604487.0                                 NaN       7.666667e+08
# 4          9814318.0                                 NaN       8.155556e+08
#
#    Inflation, consumer prices (annual %)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Life expectancy at birth, total (years)  Military expenditure (% of GDP)  \
# 0                                   32.799                              NaN
# 1                                   33.291                              NaN
# 2                                   33.757                              NaN
# 3                                   34.201                              NaN
# 4                                   34.673                              NaN
#
#    Fossil fuel energy consumption (% of total)  GDP growth (annual %)  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
#
#    Birth rate, crude (per 1,000 people)  Hospital beds (per 1,000 people)
# 0                                50.516                          0.170627
# 1                                50.566                               NaN
# 2                                50.666                               NaN
# 3                                50.787                               NaN
# 4                                50.852                               NaN

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame
